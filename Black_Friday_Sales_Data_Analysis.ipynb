# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sng

# %% [markdown]
# # #(1)Walkthrough the data set

# %%
df=pd.read_csv("black_friday.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1
# 0                          2               0                   3  \
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category
# 0       1000001  P00069042      F   0-17          10             A  \
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1
# 0                               2               0                   3  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # #(2)Analyzing the columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
print(df["User_ID"].nunique())
df["User_ID"].unique()
# Out:
# 5891
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
print(df["Product_ID"].nunique())
df["Product_ID"].unique()
# Out:
# 3623
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
print(df["Gender"].nunique())
df["Gender"].unique()
# Out:
# 2
# array(['F', 'M'], dtype=object)

# %%
print(df["Occupation"].nunique())
df["Occupation"].unique()
# Out:
# 21
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
print(df["City_Category"].nunique())
df["City_Category"].unique()
# Out:
# 3
# array(['A', 'C', 'B'], dtype=object)

# %%
print(df["Stay_In_Current_City_Years"].nunique())
df["Stay_In_Current_City_Years"].unique()
# Out:
# 5
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
print(df["Marital_Status"].nunique())
df["Marital_Status"].unique()
# Out:
# 2
# array([0, 1], dtype=int64)

# %%
print(df["Product_Category_1"].nunique())
df["Product_Category_1"].unique()
# Out:
# 18
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
print(df["Purchase"].nunique())
df["Purchase"].unique()
# Out:
# 17959
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %%
df["Purchase"].sum() ### total sale
# Out:
# 5017668378

# %%
### now all the thing can be done with the help of one for loop
for i in df.columns:
    print(df[i].nunique(),"\t:",i)
# Out:
# 5891 	: User_ID
# 3623 	: Product_ID
# 2 	: Gender
# 7 	: Age
# 21 	: Occupation
# 3 	: City_Category
# 5 	: Stay_In_Current_City_Years
# 2 	: Marital_Status
# 18 	: Product_Category_1
# 17959 	: Purchase

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %% [markdown]
# # #(3)Analyzing Gender

# %%
data=pd.DataFrame({"Ratio":[len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]}, index=["Male","Female"])
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
#### METHOD(1)
data.plot.pie(y="Ratio",autopct="%.2f%%",figsize=(6,6),wedgeprops={"edgecolor":"black","linewidth":3})
# Out:
# <Axes: ylabel='Ratio'>

# %%
#### METHOD(2)
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind="pie",autopct="%.2f%%",figsize=(6,6),wedgeprops={"edgecolor":"black","linewidth":3},title="PIE_CHART")
# Out:
# <Axes: title={'center': 'PIE_CHART'}>

# %%
df.groupby('Gender').size().plot(kind="bar",figsize=(5,5))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender')

# %%
#df.groupby('Gender').mean()['Purchase'],plot(kind="pie",autopct="%.2f%%")

# %%
#df.groupby('Gender').sum()['Purchase'],plot(kind="pie",autopct="%.2f%%")

##### here amount is string type

# %%
type(df['Purchase'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # #(4)Analyzing  Age and Marital Status

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370  \
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MARITAL_GENDER
# 0            F_0
# 1            F_0
# 2            F_0
# 3            F_0
# 4            M_0

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind="bar",figsize=(10,6),title="Purchase Distribution By Age")
# Out:
# <Axes: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %%
for i in df['Age'].unique():
    print(i,df[df["Age"]==i]['Product_ID'].nunique())
# Out:
# 0-17 2300
# 55+ 2573
# 26-35 3419
# 46-50 3099
# 51-55 2877
# 36-45 3318
# 18-25 3213

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df["Age"]==i]['Product_ID'].nunique()])
lst
# Out:
# [['0-17', 2300],
#  ['55+', 2573],
#  ['26-35', 3419],
#  ['46-50', 3099],
#  ['51-55', 2877],
#  ['36-45', 3318],
#  ['18-25', 3213]]

# %%
pd.DataFrame(lst,index=['A','B','C',"D","E","F","G"],columns=["Age","Purchase"])
# Out:
#      Age  Purchase
# A   0-17      2300
# B    55+      2573
# C  26-35      3419
# D  46-50      3099
# E  51-55      2877
# F  36-45      3318
# G  18-25      3213

# %%
data=pd.DataFrame(lst,columns=['Age','Purchase'])

# %%
data
# Out:
#      Age  Purchase
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind="bar",figsize=(10,5))
# Out:
# <Axes: >

# %%
data.plot(kind="bar",x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum().plot(kind="bar",figsize=(8,6),title='Amount Spend By Age')
# Out:
# <Axes: title={'center': 'Amount Spend By Age'}, xlabel='Age'>

# %%
df.groupby("Age").sum()['Purchase'].plot(kind="bar",figsize=(8,6),title='Amount Spend By Age')
# Out:
# <Axes: title={'center': 'Amount Spend By Age'}, xlabel='Age'>

# %%
#df.groupby("Age").mean()['Purchase']

# %%
#df.groupby("Age").mean()['Purchase'].plot(kind="bar",figsize=(8,6),title='Amount Spend By Age')

# %%
#df.groupby("Age").mean()['Purchase'].plot(kind="pie",autopct='%.2f%%',figsize=(8,6),title='Mean Amount Spend By Age')

# %%
df.groupby("Age").sum()['Purchase']
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.groupby("Age").sum()
# Out:
#             User_ID                                         Product_ID
# Age
# 0-17    14746359773  P00069042P00248942P00087842P00085442P00112542P...  \
# 18-25   97904093780  P00366542P00190742P00151842P00112642P00118442P...
# 26-35  215350137743  P00193542P00274942P00251242P00014542P00031342P...
# 36-45  107824726995  P00036842P00085942P00118742P00297942P00266842P...
# 46-50   44666364150  P00184942P00346142P0097242P00129542P00140742P0...
# 51-55   37728982395  P00231342P00190242P0096642P00058442P00019342P0...
# 55+     20964683314  P00285442P00117442P00322042P00216342P00329342P...
#
#                                                   Gender  Occupation
# Age
# 0-17   FFFFMMMMMMMMMMMMFFFFFFFFFFFFFFFFFFFFFFFMMMFFFF...      129278  \
# 18-25  FFFFFFFFFFFFFFFMMMMMMMMMMMMMMMMMMFFFFFFFFFFMMF...      657774
# 26-35  MMMMMMMMMMMMMMMMFFFMMMMMMMMMMMFFFMMMMMMMMMMMMM...     1696554
# 36-45  MFFFFFFFFFFFFFFFFFFMFFMMMMMMMMMMMMMMMMFFFMMMMF...      951060
# ...

# %%
df.groupby("Marital_Status").size().plot(kind="pie",autopct='%.2f%%',figsize=(5,5),title='Marital_Status')
# Out:
# <Axes: title={'center': 'Marital_Status'}>

# %%
df.groupby("Gender").size().plot(kind="pie",autopct='%.2f%%',figsize=(5,5),title='Gender ratio')
# Out:
# <Axes: title={'center': 'Gender ratio'}>

# %% [markdown]
# # #(5)MultiColumn Analysis

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(10,5),title="Purchase Distribution By Age")
# Out:
# <Axes: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %%
sng.set(rc={'figure.figsize':(10,5)})
sng.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sng.set(rc={'figure.figsize':(10,5)})
sng.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sng.set(rc={'figure.figsize':(5,6)})
sng.countplot(x="Gender",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sng.set(rc={'figure.figsize':(5,6)})
sng.countplot(x="Marital_Status",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sng.countplot(x=df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(5,3)})
sng.countplot(x="City_Category",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.countplot(x=df["City_Category"],hue="Age",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.countplot(x="Age",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sng.countplot(x="Marital_Status",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sng.countplot(x=df["City_Category"],hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.2f%%",figsize=(6,6),wedgeprops={"edgecolor":"black","linewidth":3})
# Out:
# <Axes: >

# %%
sng.countplot(x=df["City_Category"],hue="Gender",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.countplot(x="Gender",hue=df["City_Category"],data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="%.2f%%",wedgeprops={"edgecolor":"black"})
# Out:
# <Axes: ylabel='Purchase'>

# %%
#df.groupby("City_Category").mean()["Purchase"].plot(kind="pie",autopct="%.2f%%")

# %% [markdown]
# # #(6)Occupation and Product Analysis

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
print(len(df["Product_Category_1"].unique()))
df["Product_Category_1"].unique()
# Out:
# 18
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
print(len(df["Stay_In_Current_City_Years"].unique()))
df["Stay_In_Current_City_Years"].unique()
# Out:
# 5
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
sng.countplot(x=df["Stay_In_Current_City_Years"])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
sng.countplot(x=df["Stay_In_Current_City_Years"],hue="Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sng.countplot(x=df["Stay_In_Current_City_Years"],hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(5,4)})
sng.countplot(x=df["Stay_In_Current_City_Years"],hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sng.countplot(x=df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.countplot(x=df["City_Category"],hue=df["Age"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
##df.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind="pie",autopct="%.2f%%")

# %%
###df.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind="bar")

# %%
print(len(df["Occupation"].unique()))
# Out:
# 21

# %%
sng.countplot(x=df["Occupation"])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").size().sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
 ###df.groupby("Occupation").mean()["Purchase"].sort_values().plot(kind="bar")

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values()
# Out:
# Occupation
# 8      14594599
# 9      53619309
# 18     60249706
# 13     71135744
# 19     73115489
# 11    105437359
# 5     112525355
# 10    114273954
# 15    116540026
# 3     160428450
# 6     185065697
# 2     233275393
# 16    234442330
# 14    255594745
# 20    292276985
# 12    300672105
# 17    387240355
# 1     414552829
# 7     549282744
# 0     625814811
# 4     657530393
# Name: Purchase, dtype: int64

# %%
sng.countplot(x="Occupation",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sng.countplot(x="Occupation",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").nunique()  #### ask what this table says??
# Out:
#             User_ID  Product_ID  Gender  Age  City_Category
# Occupation
# 0               688        3243       2    7              3  \
# 1               517        3020       2    7              3
# 2               256        2892       2    7              3
# 3               170        2657       2    6              3
# 4               740        3174       2    6              3
# 5               111        2344       2    6              3
# 6               228        2724       2    6              3
# 7               669        3070       2    7              3
# 8                17        1026       2    7              3
# 9                88        1820       2    6              3
# 10              192        2110       2    5              3
# 11              128        2235       2    7              3
# 12              376        2664       2    7              3
# 13              140        1946       2    5              3
# ...

# %%
df.groupby("Occupation").nunique()["Product_ID"].plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").nunique()["Product_ID"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Product_Category_1").size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby("Product_Category_1").size().sort_values()
# Out:
# Product_Category_1
# 9        404
# 17       567
# 14      1500
# 18      3075
# 7       3668
# 12      3875
# 10      5032
# 13      5440
# 15      6203
# 16      9697
# 4      11567
# 3      19849
# 6      20164
# 2      23499
# 11     23960
# 8     112132
# 1     138353
# 5     148592
# dtype: int64

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="pie",autopct="%.0f%%")
# Out:
# <Axes: >

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="pie",autopct="%.0f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
#### df.groupby("Product_Category_1").mean()["Purchase"].sort_values().plot(kind="bar")

# %%
print(len(df["Product_ID"].unique()))
# Out:
# 3623

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df.groupby("Product_ID").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID").size().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
## df.groupby("Product_ID").mean()["Purchase"].nlargest(10).sort_values().plot(kind="bar")

# %%
sng.countplot(x="Product_Category_1",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sng.countplot(x="Product_Category_1",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # #(7)Combinging Marital and Gender Status

# %%
df.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422

# %%
for i in range(len(df)): 
    print(i)
    break
# Out:
# 0

# %%
for i in range(len(df)):
    print(str(df["Gender"][i])+"_"+str(df["Marital_Status"][i]))
    break
# Out:
# F_0

# %%
df["Gender"]
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %%
lst=[]
for i in range(len(df)):
    lst.append(str(df["Gender"][i])+"_"+str(df["Marital_Status"][i]))
df["MARITAL_GENDER"]=lst
df.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category
# 0  1000001  P00069042      F  0-17          10             A  \
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370  \
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
#
#   MARITAL_GENDER
# 0            F_0
# 1            F_0
# 2            F_0

# %%
sng.countplot(x="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='MARITAL_GENDER', ylabel='count'>

# %%
df.groupby("MARITAL_GENDER").size().plot(kind="bar")
# Out:
# <Axes: xlabel='MARITAL_GENDER'>

# %%
df.groupby("MARITAL_GENDER").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
sng.set(rc={"figure.figsize":(8,5)})
sng.countplot(x="Age",hue="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(15,7)})
sng.countplot(x="Product_Category_1",hue="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(8,5)})
sng.countplot(x="Stay_In_Current_City_Years",hue="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(8,5)})
sng.countplot(x="City_Category",hue="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sng.set(rc={"figure.figsize":(20,10)})
sng.countplot(x="Occupation",hue="MARITAL_GENDER",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>
